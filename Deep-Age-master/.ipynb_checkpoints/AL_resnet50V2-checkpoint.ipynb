# %%
import pydot
import numpy as np

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 1.15.0

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/compat/v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
import pandas as pd
import h5py

# %%
import numpy as np
from scipy import interp
import matplotlib.pyplot as plt
from itertools import cycle
from sklearn.metrics import roc_curve, auc
from sklearn.multiclass import OneVsRestClassifier
from sklearn.datasets import make_classification
from sklearn.preprocessing import label_binarize
from scipy import interp
from sklearn.metrics import confusion_matrix
import seaborn as sn
from sklearn.metrics import classification_report

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import os
from sklearn.model_selection import train_test_split

# %matplotlib inline
plt.rcParams['figure.figsize'] = (5.0, 4.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %%
import warnings
warnings.simplefilter(action='ignore', category = FutureWarning )

# %%
from keras.preprocessing import image
from keras.applications.imagenet_utils import preprocess_input
from keras.utils import to_categorical

from keras import layers
from keras.layers import Input, Dense, Activation, Dropout, BatchNormalization, Flatten, Conv1D , Reshape, Add, Concatenate
from keras.layers import AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D, GlobalAveragePooling2D , Flatten, Conv2D, ZeroPadding2D
from keras.models import Sequential, Model

from keras.optimizers import RMSprop , SGD, Adam
from keras.callbacks import ModelCheckpoint

import keras.backend as K

K.set_image_data_format('channels_last')

# %%
from collections import defaultdict
import itertools

# %%
from keras.layers import LSTM, Cropping2D, Lambda, RepeatVector, Permute, Dot, Multiply
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model

# %%
from keras.applications.resnet_v2 import ResNet152V2, ResNet50V2
input_shape = (256, 256, 3)
num_classes = 14
resnet_input_tensor = Input(shape=(256, 256, 3))

# %%
# %load_ext autoreload
# %autoreload 2
from PIL import Image
import cv2
from keras.models import load_model

# %%
sess = tf.Session()

from keras import backend as K
K.set_session(sess)

# %% [markdown]
# ### Defined functions for metrics

# %%
def metrics(model, X_test, Y_test):
    snn_pred = model.predict(X_test, batch_size=32, verbose=1) 
    snn_predicted = np.argmax(snn_pred, axis=1)
    
    model_metrics= model.evaluate(X_test, Y_test)
    print(model)
    print("model accuracy on test data is : {}" .format(model_metrics[1]))
    #Confusion Matrix
    snn_cm = confusion_matrix(np.argmax(Y_test, axis=1), snn_predicted) 

    # Visualization
    snn_df_cm = pd.DataFrame(snn_cm, range(14), range(14)) 
    plt.figure(figsize = (20,14)) 
    sn.set(font_scale=1.4) #for label size 
    sn.heatmap(snn_df_cm, annot=True, annot_kws={"size": 12}) # font size 
    plt.show()
    
    snn_report = classification_report(np.argmax(Y_test, axis=1), snn_predicted)
    print(snn_report)
    
    # Plot linewidth.
    lw = 2

    # Compute ROC curve and ROC area for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(num_classes):
        fpr[i], tpr[i], _ = roc_curve(Y_test[:, i], snn_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    # Compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], _ = roc_curve(Y_test.ravel(), snn_pred.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

    # Compute macro-average ROC curve and ROC area

    # First aggregate all false positive rates
    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(num_classes)]))

    # Then interpolate all ROC curves at this points
    mean_tpr = np.zeros_like(all_fpr)
    for i in range(num_classes):
        mean_tpr += interp(all_fpr, fpr[i], tpr[i])

    # Finally average it and compute AUC
    mean_tpr /= num_classes

    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

    # Plot all ROC curves
    plt.figure(1, figsize=(15, 10), dpi=80)
   
    colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'pink', 'black', 'red', 'yellow', 'green', 'brown', 'black', 'purple','indigo','darkgreen','darkblue'])
    for i, color in zip(range(num_classes), colors):
        plt.plot(fpr[i], tpr[i], color=color, lw=lw,
                label='ROC curve of class {0} (area = {1:0.2f})'
                ''.format(i, roc_auc[i])) 

    plt.plot([0, 1], [0, 1], 'k--', lw=lw)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic to multi-class')
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# ## Prepare Data

# %%
import h5py
from pathlib import Path
root_path = ''
hdf5_dir = Path(root_path + "data/hdf5/")
print(hdf5_dir)
# Out:
# data/hdf5

# %%
def read_hdf5(path):
    
    train_images, train_labels = [], []
    test_images, test_labels = [], []

    # Open the HDF5 file
    file = h5py.File(hdf5_dir / "train_test_data.h5", "r+")

    train_images = np.array(file["/train_images"]).astype("uint8")
    train_labels = np.array(file["/train_meta"]).astype("uint8")
    test_images = np.array(file["/test_images"]).astype("uint8")
    test_labels = np.array(file["/test_meta"]).astype("uint8")

    return train_images, train_labels ,test_images, test_labels

# %%
X_train_input , Y_train_input, X_test_input, Y_test_input = read_hdf5('train_test_data')

# %%
print(X_train_input.shape)
print(X_test_input.shape)
print(Y_train_input.shape)
print(Y_test_input.shape)
# Out:
# (18966, 256, 256, 3)
# (4742, 256, 256, 3)
# (18966, 3)
# (4742, 3)

# %%
num_classes = int(np.max(Y_train_input[:, 2]))
print("number of classes are: {}" .format(num_classes))
#dummy_classes_var = len(np.unique(Y_train_input[:, 2]))
#print( " dummy classes variable test {}" .format(dummy_classes_var))
# Out:
# number of classes are: 14

# %%
X_train_input1 = X_train_input.astype('float32')
X_test_input1 = X_test_input.astype('float32')

# %%
X_train_input1 = X_train_input1/255.
X_test_input1 = X_test_input1/255.

# %%
plt.imshow(X_train_input1[100])

# %%
X_train_preprocessed = preprocess_input(X_train_input)
print(X_train_preprocessed.shape)
X_test_preprocessed = preprocess_input(X_test_input)
print(X_test_preprocessed.shape)

### With preprocess
plt.imshow(X_train_preprocessed[100])
# Out:
# (18966, 256, 256, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (4742, 256, 256, 3)

# %%
Y_train_age_group = Y_train_input[:, 2]
print(Y_train_age_group)
Y_train_age_group_0 = np.subtract(Y_train_age_group , 1)
print(Y_train_age_group_0)
Y_train_age_group_onehot = to_categorical(Y_train_age_group_0, num_classes= num_classes)
print(Y_train_age_group_onehot.shape)

Y_test_age_group = Y_test_input[:, 2]
print(Y_test_age_group)
Y_test_age_group_0 = np.subtract(Y_test_age_group , 1)
print(Y_test_age_group_0)
Y_test_age_group_onehot = to_categorical(Y_test_age_group_0, num_classes= num_classes)
print(Y_test_age_group_onehot.shape)
# Out:
# [11  9 10 ...  8  1  7]
# [10  8  9 ...  7  0  6]
# (18966, 14)
# [7 5 6 ... 4 7 4]
# [6 4 5 ... 3 6 3]
# (4742, 14)

# %%
### Assign train and test data
X_train = X_train_input1

X_test = X_test_input1

Y_train = Y_train_age_group_onehot

Y_test = Y_test_age_group_onehot

pixel_size = int(X_train.shape[1])

#num_examples = int(X_train_original.shape[0])

print("number of classes are : {}" .format(num_classes))

input_shape = (pixel_size, pixel_size , 3)


print(sum(Y_train[: , 4] == 1))
# Out:
# number of classes are : 14
# 2200

# %% [markdown]
# ### Data Augmentation

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
# This will do preprocessing and realtime data augmentation:
datagen = ImageDataGenerator(
            # set input mean to 0 over the dataset
            featurewise_center=True,              ### changed to true
            # set each sample mean to 0
            samplewise_center=False,
            # divide inputs by std of dataset
            featurewise_std_normalization=True,        ### changed to true
            # divide each input by its std
            samplewise_std_normalization=False,
            # apply ZCA whitening
            zca_whitening=False,
            # epsilon for ZCA whitening
            zca_epsilon=1e-06,
            # randomly rotate images in the range (deg 0 to 180)
            rotation_range=10,
            # randomly shift images horizontally
            width_shift_range=0.1,
            # randomly shift images vertically
            height_shift_range=0.1,
            # set range for random shear
            shear_range=0.2,
            # set range for random zoom
            zoom_range=0,
            # set range for random channel shifts
            channel_shift_range=0.,
            # set mode for filling points outside the input boundaries
            fill_mode='nearest',
            # value used for fill_mode = "constant"
            cval=0.,
            # randomly flip images
            horizontal_flip=True,
            # randomly flip images
            vertical_flip=False,
            # set rescaling factor (applied before any other transformation)
            rescale=None,
            # set function that will be applied on each input
            preprocessing_function=None,
            # image data format, either "channels_first" or "channels_last"
            data_format='channels_last',
            # fraction of images reserved for validation (strictly between 0 and 1)
            validation_split=0.2)

# %%
# datagen.fit(X_train)

# %%
# Run training, with or without data augmentation.

def train_func(model ,x_train, y_train, datagen , data_augmentation = False, batch_size = 64, epochs = 10, validation_split =0.2 , \
               callbacks = None,\
               root_path='' , save_model = True, model_name=''  ):
    if not data_augmentation:
        print('Not using data augmentation.')
        model_history = model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_split=validation_split,
              shuffle=True,
              callbacks=callbacks)
        data_aug = 'noaug'
    else:
        print('Using real-time data augmentation.')
        
        print("fitting the model using fit_generator !!!!")
        # Fit the model on the batches generated by datagen.flow().
        model_history = model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size, subset='training'),
                        validation_data = datagen.flow(x_train, y_train, batch_size=batch_size, subset='validation') ,
                        epochs=epochs, shuffle=True,workers = 4, 
                        callbacks=callbacks)
        data_aug = 'aug'
    if save_model:
        model.save(root_path + 'saved_models/' + "{}_{}_{}_{}.h5".format(model_name,data_aug, epochs, batch_size ))    
    return model_history

# %% [markdown]
# ### Callbacks

# %%
# Prepare model model saving directory.
version = 1
model_type = 'alresnet_model%d' % (version)
save_dir = os.path.join(root_path, 'saved_models')
print(save_dir)
model_name = 'alresnet_model_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
alresnet_model_checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True)
alresnet_model_callbacks = [alresnet_model_checkpoint]
# Out:
# saved_models

# %% [markdown]
# ## Model

# %%
def tf_crop_and_resize_batches_of_arrays_mine(image_input, boxes_input , crop_size ):
    box_ind_processed = tf.range(tf.shape(image_input)[0])
    
    # print("shape of box_ind {}" .format(box_ind_processed))
    # batch_ids = tf.squeeze(tf.slice(boxes_input, [0, 0], [-1, 1], name="batch_id"))
    # num_boxes = tf.shape(boxes_input)[0]
    # batch_inds = tf.zeros([num_boxes], dtype=tf.int32, name='batch_inds')
    
    cropped_image = tf.image.crop_and_resize(image_input,
                        boxes_input, box_indices = box_ind_processed,
                        crop_size = (8,8) , method='bilinear' )
    return cropped_image

# %%
squeezor2 = Lambda(lambda x: K.squeeze(x,axis=-1), name = 'squeezor2')
expandor = Lambda(lambda x: K.expand_dims(x, axis=-1) , name = 'expandor')
concatenator = Lambda(lambda x: K.concatenate(x, axis=-1), name = 'concatenator')
# lstm_cell = LSTM(128, activation='tanh', recurrent_activation='sigmoid',   \
#                                              return_sequences=False, return_state=True, stateful=False, unroll=False)


lstm_cell = LSTM(128, return_state=True)




# one_step_attention_layer = Lambda(one_step_attention, name='attention_layer')

# %%
# normalizer = Lambda(lambda x: x/float(tf.reduce_sum(x)), name = 'normalizer')

# %%
def keras_crop_and_resize_batches_of_arrays(image_input, boxes_input, crop_size=(10, 10)):
    def f_crop(packed):
        image, boxes = packed
        return tf_crop_and_resize_batches_of_arrays_mine(image, boxes, crop_size)
    return Lambda(f_crop , name = 'crop_and_resize')([image_input, boxes_input])

# %%
resnet50_model = load_model(save_dir + '/resnet50V2_noaug_40_64.h5' , \
                      custom_objects={'tf':tf, 'keras' : keras  , 
                                     'tf_crop_and_resize_batches_of_arrays_mine' : tf_crop_and_resize_batches_of_arrays_mine })
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %%
resnet50_model.load_weights(save_dir + '/Resnet50V2_Resnet50V21_model.010.h5')

# %%
resnet50_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model_1 (Model)              (None, 2048)              23564800
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dense_2 (Dense)              (None, 14)                7182
# =================================================================
# Total params: 24,621,070
# Trainable params: 24,575,630
# Non-trainable params: 45,440
# _________________________________________________________________

# %% [markdown]
# ### Accuracy of Resnet50_V2 Model on test data

# %%
metrics(resnet50_model, X_test, Y_test)

# %% [markdown]
# ## AL-Resnet Model

# %%
# state_h = np.zeros((18966, 128))
# state_c = np.zeros((18966, 128))
# lstm_output = np.zeros((18966, 128))

# %%
def alresnet_model_imp(input_shape ):

    # resnet50_input_tensor = Input(input_shape, name = 'resnet50_input_tensor')
    
    # state_h_0 = Input((128,), name = 'state_h_0')
    # state_c_0 = Input((128,), name = 'state_c_0')
    # lstm_output_0 = Input((128,), name = 'lstm_output_0')
    # state_h = state_h_0
    # state_c = state_c_0
    # lstm_output = lstm_output_0
    
    resnet50_input = resnet50_model.layers[0].get_layer(index = 0).input
    resnet50_output = resnet50_model.layers[0].get_layer(index = -2).output
    
    resnet50_inside = Model(inputs=resnet50_input, outputs=resnet50_output)
    
    for resnet_layer in resnet50_inside.layers:
        resnet_layer.trainable = False

    X = resnet50_inside(resnet50_input)
    
    X1 = GlobalAveragePooling2D()(X)
    
    X1 = Dense(512, activation='relu' , name = 'fully_connected_global')(X1)
    
    
    X1 = Reshape((512, 1))(X1)
    
    # context, attn_states = attn_layer([X1, lstm_output])
    
    # context = one_step_attention(X1, lstm_output)
    
    lstm_output, state_h , state_c = lstm_cell(X1)
    
    # lstm_output, state_h , state_c  = lstm_cell(context, initial_state = [state_h, state_c])
    
    state_hc = concatenator([state_h, state_c])
    state_hc = expandor(state_hc)

    L_4 = Conv1D(filters = 1, kernel_size = 250 , strides = 2, padding='valid',activation = 'sigmoid')(state_hc)
    

    L_4_squeezed = squeezor2(L_4)

    # print(L_4_squeezed.shape)


    # cropped_image = tf_crop_and_resize_batches_of_arrays_mine(X, L_4_squeezed, (8, 8))

    cropped_image = keras_crop_and_resize_batches_of_arrays(X, L_4_squeezed, crop_size=(8, 8))
    
    # print(cropped_image.shape)
    
    X_final = AveragePooling2D(pool_size=(8, 8))(cropped_image)
    
    X_final = Flatten()(X_final)
    
    X_final = Dense(num_classes, activation='softmax')(X_final)
    
    # print(X_final.shape)
    
    alresnet_model = Model(inputs = resnet50_input, outputs = X_final)
    
    return alresnet_model

# %%
alresnet_model = alresnet_model_imp(input_shape= (256, 256 , 3))
alresnet_model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py:4074: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# model_1 (Model)                 (None, 8, 8, 2048)   23564800    input_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 2048)         0           model_1[1][0]
# __________________________________________________________________________________________________
# fully_connected_global (Dense)  (None, 512)          1049088     global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 512, 1)       0           fully_connected_global[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 128), (None, 66560       reshape_1[0][0]
# __________________________________________________________________________________________________
# concatenator (Lambda)           (None, 256)          0           lstm_1[0][1]
#                                                                  lstm_1[0][2]
# __________________________________________________________________________________________________
# expandor (Lambda)               (None, 256, 1)       0           concatenator[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 4, 1)         251         expandor[0][0]
# __________________________________________________________________________________________________
# squeezor2 (Lambda)              (None, 4)            0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# crop_and_resize (Lambda)        (None, 8, 8, 2048)   0           model_1[1][0]
#                                                                  squeezor2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 2048)   0           crop_and_resize[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2048)         0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 14)           28686       flatten_1[0][0]
# ==================================================================================================
# Total params: 24,709,385
# Trainable params: 1,144,585
# Non-trainable params: 23,564,800
# __________________________________________________________________________________________________

# %%
adam = Adam(lr=0.01, beta_1=0.9, beta_2=0.99, amsgrad=False)
sgd = SGD(lr=0.01, momentum=0.9, nesterov=True)
rms_prop = RMSprop(lr=0.001, rho =0.9)

# %%
alresnet_model.compile(loss= 'categorical_crossentropy' ,
              optimizer = sgd,
               metrics=['accuracy'] )

# %%
alresnet_model_history = train_func(model = alresnet_model ,x_train = X_train, y_train = Y_train, \
             datagen = datagen ,data_augmentation = False, batch_size = 64, callbacks = alresnet_model_callbacks , \
           epochs = 50, validation_split =0.1 , \
               root_path = '', save_model = True, model_name= 'ALResnet50')
# Out:
# Not using data augmentation.
# Train on 17069 samples, validate on 1897 samples
# Epoch 1/10
# 17069/17069 [==============================] - 148s 9ms/step - loss: 0.4433 - accuracy: 0.8831 - val_loss: 2.1918 - val_accuracy: 0.4027
#
# Epoch 00001: val_accuracy improved from -inf to 0.40274, saving model to saved_models/alresnet_model_alresnet_model1_model.001.h5
# Epoch 2/10
# 17069/17069 [==============================] - 143s 8ms/step - loss: 0.3025 - accuracy: 0.9241 - val_loss: 2.1649 - val_accuracy: 0.3943
#
# Epoch 00002: val_accuracy did not improve from 0.40274
# Epoch 3/10
# 17069/17069 [==============================] - 141s 8ms/step - loss: 0.2788 - accuracy: 0.9276 - val_loss: 2.2056 - val_accuracy: 0.4048
#
# Epoch 00003: val_accuracy improved from 0.40274 to 0.40485, saving model to saved_models/alresnet_model_alresnet_model1_model.003.h5
# Epoch 4/10
# 17069/17069 [==============================] - 141s 8ms/step - loss: 0.2640 - accuracy: 0.9308 - val_loss: 2.3381 - val_accuracy: 0.4133
#
# Epoch 00004: val_accuracy improved from 0.40485 to 0.41328, saving model to saved_models/alresnet_model_alresnet_model1_model.004.h5
# Epoch 5/10
# 17069/17069 [==============================] - 141s 8ms/step - loss: 0.2501 - accuracy: 0.9336 - val_loss: 2.2442 - val_accuracy: 0.4164
#
# Epoch 00005: val_accuracy improved from 0.41328 to 0.41645, saving model to saved_models/alresnet_model_alresnet_model1_model.005.h5
# Epoch 6/10
# 17069/17069 [==============================] - 141s 8ms/step - loss: 0.2368 - accuracy: 0.9355 - val_loss: 2.4607 - val_accuracy: 0.4085
#
# Epoch 00006: val_accuracy did not improve from 0.41645
# Epoch 7/10
# 17069/17069 [==============================] - 142s 8ms/step - loss: 0.2299 - accuracy: 0.9367 - val_loss: 2.4591 - val_accuracy: 0.4075
#
# Epoch 00007: val_accuracy did not improve from 0.41645
# Epoch 8/10
# 17069/17069 [==============================] - 141s 8ms/step - loss: 0.2205 - accuracy: 0.9384 - val_loss: 2.3987 - val_accuracy: 0.4122
#
# Epoch 00008: val_accuracy did not improve from 0.41645
# Epoch 9/10
# 17069/17069 [==============================] - 141s 8ms/step - loss: 0.2179 - accuracy: 0.9396 - val_loss: 2.3661 - val_accuracy: 0.3911
#
# Epoch 00009: val_accuracy did not improve from 0.41645
# Epoch 10/10
# 17069/17069 [==============================] - 140s 8ms/step - loss: 0.2074 - accuracy: 0.9416 - val_loss: 2.5337 - val_accuracy: 0.4117
#
# Epoch 00010: val_accuracy did not improve from 0.41645

# %%
plot_model(alresnet_model, show_shapes= True, to_file='alresnet_model.png')
SVG(model_to_dot(alresnet_model).create(prog='dot', format='svg'))

# %% [markdown]
# ## Test AL-RESNET on test data based on local features

# %%
metrics(alresnet_model, X_test, Y_test)

# %% [markdown]
# ## AL-Resnet based on both Global and Local Features

# %%
# Prepare model model saving directory.

model_type = 'big_model%d' % (version)

model_name = 'big_model_%s_model.{epoch:03d}.h5' % model_type
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
big_model_checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True)
big_model_callbacks = [big_model_checkpoint]

# %%
W1 = Lambda(lambda x: x , name = 'W1_mul')
W2_mul = Lambda(lambda x: x * (0.5) , name = 'W2_mul')
W_div = Lambda(lambda x: x/float(1.5) , name = 'W_div')

# %%
def big_model(input_shape, alresnet_model):
    
    resnet_input = Input(input_shape, name ='resnet_input')
    
    # resnet50_input = resnet50_model.get_layer(index=-2).output
    # resnet50_output = resnet50_model.get_layer(index=-2).output
    
    resnet50_input = resnet50_model.layers[0].get_layer(index = 0).input
    resnet50_output = resnet50_model.layers[0].get_layer(index = -2).output
    
    resnet50_global = Model(inputs=resnet50_input, outputs=resnet50_output, name = 'AL-Resnet_Global')
    
    for resnet_layer in resnet50_global.layers:
        resnet_layer.trainable = False
    
    resnet50_output = resnet50_global(resnet_input)
    
    X= resnet50_output
    
    X1 = GlobalAveragePooling2D()(X)
    # print(X.shape)
    
    # X = Flatten()(X)
    
    X1 = Dense(256, activation = 'relu', name = 'fully_connected_X1')(X1)
    
    X1 = Dense(num_classes, activation = 'softmax' , name = 'softmax_X1')(X1)
    
    
    alresnet_input = alresnet_model.layers[0].input
    alresnet_output = alresnet_model.layers[-2].output
    alresnet_local_model = Model(inputs = alresnet_input ,
                                 outputs = alresnet_output, name = 'AL-Resnet-Local')
    
    
    
    alresnet_X = alresnet_local_model(resnet_input)
    
    #alresnet_X = alresnet_model.layers[-3].output
    
    X2 = Dense(256, activation = 'relu',  name = 'fully_connected_X2')(alresnet_X)
    
    X2 = Dense(num_classes, activation = 'softmax' , name = 'softmax_X2')(X2)
    
    X2_mul = W2_mul(X2)
    
    X_final = Add()([X1 , X2_mul])
    
    X_final = W_div(X_final)
    
    big_model = Model(inputs = resnet_input , outputs = X_final, name = 'AL-Resnet-Full')
    
    return big_model

# %%
# alresnet_model.layers

# %%
# print(alresnet_model.layers[0])
# print(alresnet_model.layers[])

# print(alresnet_model.layers[11])

# print(alresnet_model.layers[-3])

# %%
big_model = big_model(input_shape=input_shape , alresnet_model = alresnet_model)
big_model.summary()
# Out:
# Model: "AL-Resnet-Full"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# resnet_input (InputLayer)       (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# AL-Resnet_Global (Model)        (None, 8, 8, 2048)   23564800    resnet_input[0][0]
# __________________________________________________________________________________________________
# AL-Resnet-Local (Model)         (None, 2048)         24680699    resnet_input[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 2048)         0           AL-Resnet_Global[1][0]
# __________________________________________________________________________________________________
# fully_connected_X2 (Dense)      (None, 256)          524544      AL-Resnet-Local[1][0]
# __________________________________________________________________________________________________
# fully_connected_X1 (Dense)      (None, 256)          524544      global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# softmax_X2 (Dense)              (None, 14)           3598        fully_connected_X2[0][0]
# __________________________________________________________________________________________________
# softmax_X1 (Dense)              (None, 14)           3598        fully_connected_X1[0][0]
# __________________________________________________________________________________________________
# W2_mul (Lambda)                 (None, 14)           0           softmax_X2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 14)           0           softmax_X1[0][0]
#                                                                  W2_mul[1][0]
# __________________________________________________________________________________________________
# W_div (Lambda)                  (None, 14)           0           add_2[0][0]
# ==================================================================================================
# Total params: 25,736,983
# Trainable params: 2,172,183
# Non-trainable params: 23,564,800
# __________________________________________________________________________________________________

# %%
big_model.compile(loss= 'categorical_crossentropy' ,
              optimizer = sgd,
               metrics=['accuracy'] )

# %%
big_model_history = train_func(model = big_model ,x_train = X_train , y_train = Y_train, \
             datagen = datagen ,data_augmentation = False, batch_size = 64, callbacks = big_model_callbacks , \
           epochs = 50, validation_split =0.1 , \
               root_path = '', save_model = True, model_name= 'bigmodel')
# Out:
# Not using data augmentation.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 17069 samples, validate on 1897 samples
# Epoch 1/50
# 17069/17069 [==============================] - 192s 11ms/step - loss: 0.6045 - accuracy: 0.8586 - val_loss: 2.1574 - val_accuracy: 0.4054
#
# Epoch 00001: val_accuracy improved from -inf to 0.40538, saving model to saved_models/big_model_big_model1_model.001.h5
# Epoch 2/50
# 17069/17069 [==============================] - 187s 11ms/step - loss: 0.3924 - accuracy: 0.9237 - val_loss: 2.1412 - val_accuracy: 0.4180
#
# Epoch 00002: val_accuracy improved from 0.40538 to 0.41803, saving model to saved_models/big_model_big_model1_model.002.h5
# Epoch 3/50
# 17069/17069 [==============================] - 186s 11ms/step - loss: 0.3596 - accuracy: 0.9278 - val_loss: 2.1394 - val_accuracy: 0.4170
#
# Epoch 00003: val_accuracy did not improve from 0.41803
# Epoch 4/50
# 17069/17069 [==============================] - 184s 11ms/step - loss: 0.3395 - accuracy: 0.9274 - val_loss: 2.2012 - val_accuracy: 0.4117
#
# Epoch 00004: val_accuracy did not improve from 0.41803
# Epoch 5/50
# 17069/17069 [==============================] - 184s 11ms/step - loss: 0.3114 - accuracy: 0.9320 - val_loss: 2.1441 - val_accuracy: 0.4128
#
# Epoch 00005: val_accuracy did not improve from 0.41803
# Epoch 6/50
# 17069/17069 [==============================] - 184s 11ms/step - loss: 0.2840 - accuracy: 0.9343 - val_loss: 2.2414 - val_accuracy: 0.4064
#
# Epoch 00006: val_accuracy did not improve from 0.41803
# Epoch 7/50
# 17069/17069 [==============================] - 185s 11ms/step - loss: 0.2693 - accuracy: 0.9353 - val_loss: 2.2798 - val_accuracy: 0.4080
#
# Epoch 00007: val_accuracy did not improve from 0.41803
# Epoch 8/50
# 17069/17069 [==============================] - 185s 11ms/step - loss: 0.2535 - accuracy: 0.9380 - val_loss: 2.3146 - val_accuracy: 0.4133
#
# Epoch 00008: val_accuracy did not improve from 0.41803
# Epoch 9/50
# 17069/17069 [==============================] - 184s 11ms/step - loss: 0.2395 - accuracy: 0.9388 - val_loss: 2.3808 - val_accuracy: 0.4080
#
# Epoch 00009: val_accuracy did not improve from 0.41803
# Epoch 10/50
# 17069/17069 [==============================] - 185s 11ms/step - loss: 0.2270 - accuracy: 0.9405 - val_loss: 2.3640 - val_accuracy: 0.4054
#
# Epoch 00010: val_accuracy did not improve from 0.41803
# Epoch 11/50
# 17069/17069 [==============================] - 183s 11ms/step - loss: 0.2138 - accuracy: 0.9426 - val_loss: 2.3696 - val_accuracy: 0.4112
#
# Epoch 00011: val_accuracy did not improve from 0.41803
# Epoch 12/50
# 17069/17069 [==============================] - 185s 11ms/step - loss: 0.2047 - accuracy: 0.9449 - val_loss: 2.4068 - val_accuracy: 0.3938
#
# Epoch 00012: val_accuracy did not improve from 0.41803
# Epoch 13/50
# 17069/17069 [==============================] - 185s 11ms/step - loss: 0.1907 - accuracy: 0.9459 - val_loss: 2.4546 - val_accuracy: 0.3938
#
# Epoch 00013: val_accuracy did not improve from 0.41803
# Epoch 14/50
# 17069/17069 [==============================] - 184s 11ms/step - loss: 0.1846 - accuracy: 0.9470 - val_loss: 2.5554 - val_accuracy: 0.4191
#
# Epoch 00014: val_accuracy improved from 0.41803 to 0.41908, saving model to saved_models/big_model_big_model1_model.014.h5
# Epoch 15/50
# 17069/17069 [==============================] - 186s 11ms/step - loss: 0.1727 - accuracy: 0.9501 - val_loss: 2.4991 - val_accuracy: 0.4001
#
# Epoch 00015: val_accuracy did not improve from 0.41908
# Epoch 16/50
# 17069/17069 [==============================] - 184s 11ms/step - loss: 0.1659 - accuracy: 0.9507 - val_loss: 2.5713 - val_accuracy: 0.4101
#
# Epoch 00016: val_accuracy did not improve from 0.41908
# Epoch 17/50
# 17069/17069 [==============================] - 185s 11ms/step - loss: 0.1586 - accuracy: 0.9512 - val_loss: 2.5078 - val_accuracy: 0.4022
#
# Epoch 00017: val_accuracy did not improve from 0.41908
# Epoch 18/50
# 17069/17069 [==============================] - 185s 11ms/step - loss: 0.1501 - accuracy: 0.9537 - val_loss: 2.6290 - val_accuracy: 0.4006
#
# Epoch 00018: val_accuracy did not improve from 0.41908
# Epoch 19/50
# 17069/17069 [==============================] - 184s 11ms/step - loss: 0.1473 - accuracy: 0.9544 - val_loss: 2.5482 - val_accuracy: 0.3906
#
# Epoch 00019: val_accuracy did not improve from 0.41908
# Epoch 20/50
# 17069/17069 [==============================] - 184s 11ms/step - loss: 0.1374 - accuracy: 0.9578 - val_loss: 2.6163 - val_accuracy: 0.4033
#
# Epoch 00020: val_accuracy did not improve from 0.41908
# Epoch 21/50
# 17069/17069 [==============================] - 183s 11ms/step - loss: 0.1333 - accuracy: 0.9585 - val_loss: 2.7573 - val_accuracy: 0.4091
#
# Epoch 00021: val_accuracy did not improve from 0.41908
# Epoch 22/50
# 17069/17069 [==============================] - 185s 11ms/step - loss: 0.1296 - accuracy: 0.9593 - val_loss: 2.7789 - val_accuracy: 0.4054
#
# Epoch 00022: val_accuracy did not improve from 0.41908
# Epoch 23/50
# 17069/17069 [==============================] - 184s 11ms/step - loss: 0.1237 - accuracy: 0.9622 - val_loss: 2.7409 - val_accuracy: 0.4017
#
# Epoch 00023: val_accuracy did not improve from 0.41908
# Epoch 24/50
# 17069/17069 [==============================] - 183s 11ms/step - loss: 0.1200 - accuracy: 0.9615 - val_loss: 2.7732 - val_accuracy: 0.4022
#
# Epoch 00024: val_accuracy did not improve from 0.41908
# Epoch 25/50
# 17069/17069 [==============================] - 184s 11ms/step - loss: 0.1165 - accuracy: 0.9640 - val_loss: 2.8416 - val_accuracy: 0.4080
#
# Epoch 00025: val_accuracy did not improve from 0.41908
# Epoch 26/50
# 17069/17069 [==============================] - 183s 11ms/step - loss: 0.1115 - accuracy: 0.9651 - val_loss: 2.7888 - val_accuracy: 0.3943
#
# Epoch 00026: val_accuracy did not improve from 0.41908
# Epoch 27/50
# 17069/17069 [==============================] - 185s 11ms/step - loss: 0.1078 - accuracy: 0.9665 - val_loss: 2.8100 - val_accuracy: 0.3933
#
# Epoch 00027: val_accuracy did not improve from 0.41908
# Epoch 28/50
# 17069/17069 [==============================] - 183s 11ms/step - loss: 0.1048 - accuracy: 0.9668 - val_loss: 2.8832 - val_accuracy: 0.4017
#
# Epoch 00028: val_accuracy did not improve from 0.41908
# Epoch 29/50
# 17069/17069 [==============================] - 183s 11ms/step - loss: 0.1030 - accuracy: 0.9665 - val_loss: 2.8857 - val_accuracy: 0.3969
#
# Epoch 00029: val_accuracy did not improve from 0.41908
# Epoch 30/50
# 17069/17069 [==============================] - 185s 11ms/step - loss: 0.1019 - accuracy: 0.9670 - val_loss: 2.9779 - val_accuracy: 0.3985
#
# Epoch 00030: val_accuracy did not improve from 0.41908
# Epoch 31/50
# 17069/17069 [==============================] - 183s 11ms/step - loss: 0.0975 - accuracy: 0.9692 - val_loss: 3.0070 - val_accuracy: 0.4022
#
# Epoch 00031: val_accuracy did not improve from 0.41908
# Epoch 32/50
# 17069/17069 [==============================] - 184s 11ms/step - loss: 0.0936 - accuracy: 0.9698 - val_loss: 2.9781 - val_accuracy: 0.4043
#
# Epoch 00032: val_accuracy did not improve from 0.41908
# Epoch 33/50
# 17069/17069 [==============================] - 183s 11ms/step - loss: 0.0916 - accuracy: 0.9706 - val_loss: 3.1161 - val_accuracy: 0.3996
#
# Epoch 00033: val_accuracy did not improve from 0.41908
# Epoch 34/50
# 17069/17069 [==============================] - 184s 11ms/step - loss: 0.0912 - accuracy: 0.9701 - val_loss: 3.0250 - val_accuracy: 0.3927
#
# Epoch 00034: val_accuracy did not improve from 0.41908
# Epoch 35/50
# 17069/17069 [==============================] - 184s 11ms/step - loss: 0.0888 - accuracy: 0.9706 - val_loss: 3.0923 - val_accuracy: 0.4012
#
# Epoch 00035: val_accuracy did not improve from 0.41908
# Epoch 36/50
# 17069/17069 [==============================] - 183s 11ms/step - loss: 0.0861 - accuracy: 0.9727 - val_loss: 3.0843 - val_accuracy: 0.4022
#
# Epoch 00036: val_accuracy did not improve from 0.41908
# Epoch 37/50
# 17069/17069 [==============================] - 184s 11ms/step - loss: 0.0839 - accuracy: 0.9729 - val_loss: 3.1349 - val_accuracy: 0.4006
#
# Epoch 00037: val_accuracy did not improve from 0.41908
# Epoch 38/50
# 17069/17069 [==============================] - 183s 11ms/step - loss: 0.0832 - accuracy: 0.9734 - val_loss: 3.1114 - val_accuracy: 0.3938
#
# Epoch 00038: val_accuracy did not improve from 0.41908
# Epoch 39/50
# 17069/17069 [==============================] - 184s 11ms/step - loss: 0.0808 - accuracy: 0.9734 - val_loss: 3.2210 - val_accuracy: 0.3991
#
# Epoch 00039: val_accuracy did not improve from 0.41908
# Epoch 40/50
# 17069/17069 [==============================] - 184s 11ms/step - loss: 0.0803 - accuracy: 0.9746 - val_loss: 3.1607 - val_accuracy: 0.4017
#
# Epoch 00040: val_accuracy did not improve from 0.41908
# Epoch 41/50
# 17069/17069 [==============================] - 183s 11ms/step - loss: 0.0774 - accuracy: 0.9753 - val_loss: 3.1180 - val_accuracy: 0.3985
#
# Epoch 00041: val_accuracy did not improve from 0.41908
# Epoch 42/50
# 17069/17069 [==============================] - 184s 11ms/step - loss: 0.0773 - accuracy: 0.9742 - val_loss: 3.1871 - val_accuracy: 0.4027
#
# Epoch 00042: val_accuracy did not improve from 0.41908
# Epoch 43/50
# 17069/17069 [==============================] - 183s 11ms/step - loss: 0.0751 - accuracy: 0.9750 - val_loss: 3.2420 - val_accuracy: 0.4022
#
# Epoch 00043: val_accuracy did not improve from 0.41908
# Epoch 44/50
# 17069/17069 [==============================] - 184s 11ms/step - loss: 0.0748 - accuracy: 0.9747 - val_loss: 3.2980 - val_accuracy: 0.4038
#
# Epoch 00044: val_accuracy did not improve from 0.41908
# Epoch 45/50
# 17069/17069 [==============================] - 185s 11ms/step - loss: 0.0737 - accuracy: 0.9749 - val_loss: 3.1688 - val_accuracy: 0.3880
#
# Epoch 00045: val_accuracy did not improve from 0.41908
# Epoch 46/50
# 17069/17069 [==============================] - 184s 11ms/step - loss: 0.0724 - accuracy: 0.9756 - val_loss: 3.2461 - val_accuracy: 0.3985
#
# Epoch 00046: val_accuracy did not improve from 0.41908
# Epoch 47/50
# 17069/17069 [==============================] - 185s 11ms/step - loss: 0.0710 - accuracy: 0.9755 - val_loss: 3.2151 - val_accuracy: 0.3948
#
# Epoch 00047: val_accuracy did not improve from 0.41908
# Epoch 48/50
# 17069/17069 [==============================] - 184s 11ms/step - loss: 0.0696 - accuracy: 0.9767 - val_loss: 3.3163 - val_accuracy: 0.4017
#
# Epoch 00048: val_accuracy did not improve from 0.41908
# Epoch 49/50
# 17069/17069 [==============================] - 184s 11ms/step - loss: 0.0699 - accuracy: 0.9765 - val_loss: 3.3108 - val_accuracy: 0.3996
#
# Epoch 00049: val_accuracy did not improve from 0.41908
# Epoch 50/50
# 17069/17069 [==============================] - 184s 11ms/step - loss: 0.0681 - accuracy: 0.9768 - val_loss: 3.2982 - val_accuracy: 0.3954
#
# Epoch 00050: val_accuracy did not improve from 0.41908

# %%
# Plot training & validation loss values
plt.figure(figsize = (10, 10))
plt.plot(big_model_history.history['loss'])
plt.plot(big_model_history.history['val_loss'])
plt.title('AL-Resnet (Global and Local) Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
plt.figure(figsize = (10, 10))
# Plot training & validation accuracy values
plt.plot(big_model_history.history['accuracy'])
plt.plot(big_model_history.history['val_accuracy'])
plt.title('AL-Resnet (Global and Local) Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='center right')
plt.show()

# %%
plot_model(big_model, show_shapes= True, to_file='big_model.png')
SVG(model_to_dot(big_model).create(prog='dot', format='svg'))

# %%
metrics(model = big_model, X_test = X_test, Y_test = Y_test)
# Out:
# 4742/4742 [==============================] - 46s 10ms/step
# 4742/4742 [==============================] - 43s 9ms/step
# <keras.engine.training.Model object at 0x7fb838f1b668>
# model accuracy on test data is : 0.423239141702652
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.92       508
#            1       0.57      0.50      0.53       167
#            2       0.40      0.38      0.39        97
#            3       0.31      0.32      0.31       202
#            4       0.36      0.30      0.33       560
#            5       0.41      0.62      0.49      1017
#            6       0.21      0.17      0.19       488
#            7       0.20      0.22      0.21       352
#            8       0.17      0.10      0.13       221
#            9       0.22      0.13      0.16       223
#           10       0.25      0.16      0.19       229
#           11       0.29      0.32      0.30       193
#           12       0.26      0.26      0.26       141
#           13       0.76      0.64      0.69       344
#
#     accuracy                           0.42      4742
#    macro avg       0.38      0.36      0.37      4742
# weighted avg       0.41      0.42      0.41      4742

# %% [markdown]
# ### Load saved model and weights while training

# %%
big_model_load = load_model(save_dir + '/bigmodel_noaug_50_64.h5', 
                           custom_objects={'tf':tf, 'keras' : keras  , 
                                     'tf_crop_and_resize_batches_of_arrays_mine' : tf_crop_and_resize_batches_of_arrays_mine })
big_model_load.load_weights(save_dir + '/big_model_big_model1_model.014.h5')

# %%
metrics(model = big_model_load, X_test = X_test, Y_test = Y_test)
# Out:
# 4742/4742 [==============================] - 50s 11ms/step
# 4742/4742 [==============================] - 48s 10ms/step
# <keras.engine.training.Model object at 0x7fb7ba788cf8>
# model accuracy on test data is : 0.43167439103126526
#               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92       508
#            1       0.56      0.59      0.57       167
#            2       0.41      0.29      0.34        97
#            3       0.37      0.29      0.33       202
#            4       0.38      0.20      0.27       560
#            5       0.40      0.70      0.51      1017
#            6       0.21      0.16      0.18       488
#            7       0.25      0.15      0.19       352
#            8       0.20      0.19      0.20       221
#            9       0.22      0.17      0.19       223
#           10       0.24      0.14      0.17       229
#           11       0.28      0.31      0.29       193
#           12       0.27      0.21      0.24       141
#           13       0.74      0.67      0.71       344
#
#     accuracy                           0.43      4742
#    macro avg       0.39      0.36      0.36      4742
# weighted avg       0.42      0.43      0.41      4742
